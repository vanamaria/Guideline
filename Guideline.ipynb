# %%
#Directory of Digital Forensics tools
# C:\Users\User\Documents\Digital Forensics Tools\\

# %%
import os
import subprocess
from subprocess import *

# %%
def autopsy_instr(direc):
    inst_auto=direc+"autopsy_instructions.txt"
    file=open(inst_auto,'r')
    print(file.read())

    
def bulk_instr(direc):
    inst_bulk=direc+"bulk_instructions.txt"
    file=open(inst_bulk,'r')
    print(file.read())    


    
def magnet_instr(direc):
    inst_magnet=direc+"magnet_instructions.txt"
    file=open(inst_magnet,'r')
    print(file.read())        
    
def belka_instr(direc):
    inst_belka=direc+"belka_instructions.txt"
    file=open(inst_belka,'r')
    print(file.read())   
    
    
    
def regshot_instr(direc):
    inst_regshot=direc+"regshot_instructions.txt"
    file=open(inst_regshot,'r')
    print(file.read())
    
def processmonior_instr(direc):
    inst_procm=direc+"processmonitor_instructions.txt"
    file=open(inst_procm,'r')
    print(file.read())

def registryexplorer_instr(direc):
    inst_regex=direc+"registryexplorer_instructions.txt"
    file=open(inst_regex,'r')
    print(file.read())    
    

def hexworkshop_instr(direc):
    inst_hex=direc+"hexworkshop_instructions.txt"
    file=open(inst_hex,'r')
    print(file.read())

# %%
def autopsy_fun(dire, inst_direc1):
    auto=dire+'Autopsy'
    auto_file=os.startfile(auto) 
    print("Print instructions for how to use Autopsy")
    autopsy_instr(inst_direc1)
    print("Now you can start the memory analysis with the Autopsy ")
    
    
def bulk_fun(dire,inst_direc1):    
    bulk=dire+'Bulk Extractor'
    bulk_file=os.startfile(bulk) 
    print("Print instructions for how to use Bulk Extractor")
    bulk_instr(inst_direc1)
    print("Now you can start the memory analysis with the Bulk Extract")

# %%
def network_anal():
    dire=input("Give the directory of the stored digital forensics tools. Use '\\\\' in the end: ")
    print("NETWORK FORENSIC ANALYSIS INSTRUCTIONS")
    inst_direc=r'C:\Users\User\Documents\University Southampton\Thesis\Final\\'
    msg="Tor browsing without VPN: Press 1 , Tor browsing with VPN: Press 2     "
    case=input(msg)
    
    if case=='1':
        instructions1=inst_direc+"net_whvpn.txt"
        f=open(instructions1,'r')
        print(f.read())
        wir=dire+'Wireshark'
        wireshark_file=os.startfile(wir) 
        # %run CheckingIP.ipynb
        print("Now you have completed the first case sceario")
        net=dire+'NetworkMiner'
        print(net)
        networkminer_file=os.startfile(net)
    elif case=='2':
        instructions2=inst_direc+"net_wvpn.txt"
        ff=open(instructions2,'r')
        print(ff.read())
        wir=dire+'Wireshark'
        print(wir)
        wireshark_file=os.startfile(wir) 
        # %run CheckingIP.ipynb
        print("Now you have completed the second case sceario")
        net=dire+'NetworkMiner'
        networkminer_file=os.startfile(net)
    else:
        print("This number does not correspond to any case ")

# %%
def memory_anal():
    dire=input("Give the directory of the stored digital forensics tools. Use '\\\\' in the end: ")
    print("MEORY FORENSIC ANALYSIS INSTRUCTIONS")
    inst_direc1=r'C:\Users\User\Documents\University Southampton\Thesis\Final\\'
    dire1=r''+dire
    print("The first step is to select the tool to dump the memroy")
    msg1="FTK Imager: Press 1 , Magnet Ram Capture: Press 2 , Belasoft Live RAM Capturer: Press 3    "
    case1=input(msg1)    
    if case1=='1':
        ftk=dire1+'AccessData FTK Imager'
        ftk_file=os.startfile(ftk)  
        print("Print instructions for how to use FTK Imager")
        inst_ftk=inst_direc1+"ftk_instructions.txt"
        f1=open(inst_ftk,'r')
        print(f1.read())
        print("Select the tool to analyse the image from the memory")
        msg2="Autopsy: Press 1 , Bulk Extractor: Press 2     "
        case2=input(msg2)
        if case2=='1':
            autopsy_fun(dire,inst_direc1)
        elif case2=='2':
            bulk_fun(dire,inst_direc1)
        else:
            print("This number does not correspond to any of the tools mentioned ")
    elif case1=='2':            
        magnet=dire+'MRCv120'
        magnet_file=os.startfile(magnet)       
        print("Print instructions for how to use Magnet Ram Capture")
        magnet_instr(inst_direc1)
        print("Select the tool to analyse the image from the memory")
        msg2="Autopsy: Press 1 , Bulk Extractor: Press 2     "
        case2=input(msg2)
        if case2=='1':
            autopsy_fun(dire,inst_direc1)
        elif case2=='2':
            bulk_fun(dire,inst_direc1)
        else:
            print("This number does not correspond to any of the tools mentioned")
    elif case1=='3':    
        loc_input=input("Give the path for the Belasoft Live RAM Capturer. Choose x86 or x64. Use '\\\\' in the end: ")
        if loc_input==r'C:\Users\User\Documents\Digital Forensics Tools\RamCapturer\x64\\':
            belk1=loc_input+'RamCapture64'
            belk1_file=os.startfile(belk1)       
            print("Print instructions for how to use Belasoft Live RAM Capturer x64")
            belka_instr(inst_direc1)
        elif loc_input==r'C:\Users\User\Documents\Digital Forensics Tools\RamCapturer\x86\\':   
            belk2=loc_input+'RamCapture'
            print(belk2)
            belk2_file=os.startfile(belk2)       
            print("Print instructions for how to use Belasoft Live RAM Capturer x86")
            belka_instr(inst_direc1)
        #####miss the file!!!!!!!!!!!!!!!!!!!!!!
        else:
            print("This number does not correspond to any of the tools mentioned ")
        print("The image of the Belasoft Live RAM Capturer is analysed only with Belkasoft Evidence Center 2020(Trial)")
       #Missing Belkasoft Evidence Center 2020(Trial)!!!!!!!!!!!!!!!!!!!!!
           
        print("Now you can start the memory analysis with the Belkasoft Evidence Center 2020(Trial) tool ")
    else :
        print("This number does not correspond to any of the tools mentioned ")

# %%
def registry_anal():
    dire=input("Give the directory of the stored digital forensics tools. Use '\\\\' in the end: ")
    print("REGISTRY FORENSIC ANALYSIS INSTRUCTIONS")
    inst_direc1=r'C:\Users\User\Documents\University Southampton\Thesis\Final\\'
    dire2=r''+dire
    print("The first step is to select the tool to dump the memroy")
    msg2="Regshot: Press 1 , Proces Monitor: Press 2 , Registry Explorer: Press 3    "
    case2=input(msg2) 
    if case2=='1':
        loc_input1=input("Give the path for the Regshot.  Use '\\\\' in the end: " )
        ver=input("Choose ANSI or Unicode. Choose x86 or x64.")
        if ver=='Regshot-x64-ANSI': 
            reg=loc_input1+ver
            reg_file=os.startfile(reg)          
            print("Print instructions for how to use Regshot")
            regshot_instr(inst_direc1)
        elif ver=='Regshot-x64-Unicode': 
            reg1=loc_input1+ver
            reg1_file=os.startfile(reg1)             
            print("Print instructions for how to use Regshot")   
            regshot_instr(inst_direc1)
        elif ver=='Regshot-x86-ANSI': 
            reg2=loc_input1+ver
            reg2_file=os.startfile(reg2)            
            print("Print instructions for how to use Regshot")
            regshot_instr(inst_direc1)
        elif ver=='Regshot-x86-Unicode': 
            reg3=loc_input1+ver
            reg3_file=os.startfile(reg3)       
            print("Print instructions for how to use Regshot")
            regshot_instr(inst_direc1)
    elif case2=='2': 
        loc_input2=input("Give the path for the Process Monitor. Use '\\\\' in the end: " )
        ver1=input("Choose x86 or x64 ")
        if ver1=='Procmon': 
            proc=loc_input2+ver1
            proc_file=os.startfile(proc)          
            print("Print instructions for how to use Process Monitor")
            processmonior_instr(inst_direc1)
        elif ver1=='Procmon64': 
            proc1=loc_input2+ver1
            proc1_file=os.startfile(proc1)          
            print("Print instructions for how to use Process Monitor")
            processmonior_instr(inst_direc1)
    elif case2=='3':
        loc_input3=input("Give the path for the Registry Explorer. Use '\\\\' in the end: " )
        var3=loc_input3+'RegistryExplorer'
        #regex_file=os.startfile(var3)    
        subprocess.call(['runas', '/user:Administrator', 'ADMIN_PASS',var3])
        print("Print instructions for how to use Registry Explorer")
        registryexplorer_instr(inst_direc1)
            #subprocess.call([var3, os.path.join(root, name)])
            
        
    else :
        print("This number does not correspond to any of the tools mentioned ")

# %%
def harddisk_anal():
    dire4=input("Give the directory of the stored digital forensics tools. Use '\\\\' in the end: ")
    print("HARD DISK FORENSIC ANALYSIS INSTRUCTIONS")
    inst_direc2=r'C:\Users\User\Documents\University Southampton\Thesis\Final\\'
    print("The first step is to select the kind of the artefacts to be investigate ")
    msg3="Browsing activities: Press 1 , Snapshots of VM analysis (public keys, registries, etc): Press 2    "
    case3=input(msg3)
    if case3=='1':
        print("Browsing acitivies stored in hard disk can be investigated in two ways")
        print("Either using a tool to create a disk image or analysing .vdi file")
        msg4="Tool for disk image (FTK Imager): Press 1 , VDI file analysis: Press 2    "
        case4=input(msg4)
        if case4=='1':
            ftk1=dire4+'AccessData FTK Imager'
            ftk1_file=os.startfile(ftk1)  
            print("Print instructions for how to use FTK Imager")
            inst_ftk1=inst_direc2+"ftk1_instructions.txt"
            ff1=open(inst_ftk1,'r')
            print("Select the tool to analyse the image from the memory")
            msg5="Autopsy: Press 1 , Bulk Extractor: Press 2     "
            case5=input(msg5)
            if case5=='1':
                autopsy_fun(dire4,inst_direc2)
            elif case5=='2':
                bulk_fun(dire4,inst_direc2)
            else:
                print("This number does not correspond to any of the tools mentioned ")
        elif case4=='2':
            print("Select the tool to analyse the vdi file for browsing activities")
            msg6="Autopsy: Press 1 , Bulk Extractor: Press 2  "
            print("To analyse the vdi file using either Autopsy or Bulk Extractor, it best to convert the .vdi file to .raw format")
            print("To do this, write the following command to the command line")
            convertmsg="VBoxManage clonehd 'path/to/file/.vdi' 'paht/to/file/.raw' "  
            print(convertmsg)
            os.system("start cmd")
            case6=input(msg6)
            if case6=='1':
                autopsy_fun(dire4,inst_direc2)
            elif case6=='2':
                bulk_fun(dire4,inst_direc2)
            else:
                print("This number does not correspond to any of the tools mentioned ")
    elif case3=='2': 
        print("Snapshots in VirtualBox are .vdi files")
        print(".vdi files will be anlysed using Hex Workshop Editor, it is not necessary to be converted")
        hexwork=dire4+'Hex Workshop Hex Editor (x64)'
        hexwork_file=os.startfile(hexwork) 
        print("Print instructions for how to use Hex Workshop Hex Editor ")
        hexworkshop_instr(inst_direc2)
        print("Now you can start the hard disk analysis with the Hex Workshop Hex Editor ")
               
    else :
        print("This number does not correspond to any of the tools mentioned ")

# %%
def forensic_anal():
    print("Choose the critical area to be forensically investigated ")
    choice=input("Network forensic analysis: Press 1 , Memory forensic analysis: Press 2 , Registry forensic analysis: Press 3 , Hard Disk forensic analysis: Press 4" )
    if choice=='1':
        network_anal()
    elif choice=='2':
        memory_anal()
    elif choice=='3':
        registry_anal()
    elif choice=='4':
        harddisk_anal()
    else:
        print("This number does not correspond to any critical area ")
    
    choice1=input("If another critical area needs to be investigate press: YES , otherwise press: NO ")
    if choice1=='YES':
        forensic_anal()
    elif choice1=='NO':
        print("Forensic investigation has been finished")
    else:   
        print("This is not an accepted answer ")

# %%
if __name__ == "__main__":
    forensic_anal()
# Out:
# Choose the critical area to be forensically investigated
# Network forensic analysis: Press 1 , Memory forensic analysis: Press 2 , Registry forensic analysis: Press 3 , Hard Disk forensic analysis: Press 41
# Give the directory of the stored digital forensics tools. Use '\\' in the end: C:\Users\User\Documents\Digital Forensics Tools\\
# NETWORK FORENSIC ANALYSIS INSTRUCTIONS
# Tor browsing without VPN: Press 1 , Tor browsing with VPN: Press 2     1
# The first case is when the Tor Browser is used normally, without the user is connected to VPN
# First, open the Wireshark tool to capture the packets and select the appropriate interface
# Open Tor Browser and perform the browsing activities
# When the browsing activities have been completed, save the file as pcap
# The network analyis will be conducted using Wireshark and NetworkMiner tools
# Before use the tools, a scirpt will run to check if the IPs captured are Tor guard and/or exit nodes.
# ...
